# %% [markdown]
# <div>
#     <img src="images/emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#     <span>
#         <h1 style="padding-bottom:5px;"> AI Booster Week 01 - Python for Data Science </h1>
#         <a href="https://masters.em-lyon.com/fr/msc-in-data-science-artificial-intelligence-strategy">[Emlyon]</a> MSc in Data Science & Artificial Intelligence Strategy (DSAIS) <br/>
#          Paris | © Saeed VARASTEH
#     </span>
# </div>

# %%
#Romain THOMAS

# %% [markdown]
# <div class="alert-info" style="border-bottom: solid 1px lightgray; background-color:#ece4f5;">
#     <img src="images/assignment.png" style="height:60px; float:left; padding-right:10px;" />
#     <span style="font-weight:bold; color:#8966b0">
#         <h4 style="padding-top:25px;"> EXERCISES 05 </h4>
#     </span>
# </div>

# %% [markdown]
# ### Pandas II

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div style=' background-color:#fae8ea'>
#     <b>Q1</b> Netflix data.
# </div>
#
# You are given a file named __netflix_titles.csv__.
#
# This file contains data from a **Netflix** report, extracted by Flixable. The data columns are:
#
# - Id column
# - Type: Movie or TV Show
# - The movies or TV shows titles
# - The name of the director(s),
# - The cast (the list of actors separated by comma),
# - The country (ies) where the movie was produced,
# - The date on which it was added to Netflix,
# - The released year
# - The rating
# - The duration (in min for movies, and in number of seasons for TV shows),
# - The description
#
# <div class="alert-info">
# <b>Note:</b> Open the file to have a look at it, make a first exploration.
# </div>

# %%
data=pd.read_csv(".\\data\\netflix_titles.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8799   s8803    Movie                 Zodiac    David Fincher
# 8800   s8804  TV Show            Zombie Dumb              NaN
# 8801   s8805    Movie             Zombieland  Ruben Fleischer
# 8802   s8806    Movie                   Zoom     Peter Hewitt
# 8803   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 1- Read the file into a Pandas `DataFrame`.

# %%
# your code
df=pd.DataFrame(data)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8799   s8803    Movie                 Zodiac    David Fincher
# 8800   s8804  TV Show            Zombie Dumb              NaN
# 8801   s8805    Movie             Zombieland  Ruben Fleischer
# 8802   s8806    Movie                   Zoom     Peter Hewitt
# 8803   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 2- Display a summary of the basic information about the data.

# %%
# your code
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8804 entries, 0 to 8803
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8804 non-null   object
#  1   type          8804 non-null   object
#  2   title         8804 non-null   object
#  3   director      6170 non-null   object
#  4   cast          7979 non-null   object
#  5   country       7973 non-null   object
#  6   date_added    8794 non-null   object
#  7   release_year  8804 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8804 non-null   object
#  11  description   8804 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.5+ KB

# %%
df.shape
# Out:
# (8804, 12)

# %% [markdown]
# 3- Extract __a list__ where you can find all the released years without repetition.

# %%
# your code

release_year_list=df["release_year"].drop_duplicates()

release_year_list

#print(type(release_year_list))
# Out:
# 0       2020
# 1       2021
# 7       1993
# 21      2018
# 22      1996
#         ...
# 7787    1942
# 7836    1955
# 8416    1944
# 8584    1947
# 8657    1943
# Name: release_year, Length: 74, dtype: int64

# %% [markdown]
# 4- We have movies from which period in this dataset?
#
# __Hint:__ find the minimum and the maximum of the released years.

# %%
# your code
print(f"we have from the period from {release_year_list.min()} to {release_year_list.max()}")
# Out:
# we have from the period from 1925 to 2021

# %% [markdown]
# 5- Extract a __list__ containing all the (unique) release years of only __the movies__ in the dataset.

# %%
# your code
mask=df["type"]=="Movie"
test=df["release_year"][mask].unique()
print(test)
# Out:
# [2020 2021 1993 1996 1998 1997 2010 2013 2017 1975 1978 1983 1987 2012
#  2001 2002 2003 2004 2011 2008 2009 2007 2005 2006 2018 2019 1994 2015
#  1982 1989 2014 1990 1991 1999 2016 1986 1984 1980 1961 2000 1995 1985
#  1992 1976 1959 1988 1981 1972 1964 1954 1979 1958 1956 1963 1970 1973
#  1960 1974 1966 1971 1962 1969 1977 1967 1968 1965 1945 1946 1942 1955
#  1944 1947 1943]

# %% [markdown]
# 6- Write code to find the __average length (duration)__ (in minutes) of all the __movies__ in the dataset.

# %%
# your code
def avg_movie_length():
    avg_length=df["duration"][mask].str.replace(" min","",regex=False)
    avg_length=avg_length.astype("int")
    #print(avg_length)
    return avg_length.mean()

# %%
print("The average movie length is: ", avg_movie_length())
# Out:
# The average movie length is:  99.57718668407311

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8799   s8803    Movie                 Zodiac    David Fincher
# 8800   s8804  TV Show            Zombie Dumb              NaN
# 8801   s8805    Movie             Zombieland  Ruben Fleischer
# 8802   s8806    Movie                   Zoom     Peter Hewitt
# 8803   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8799    False  False  False     False  False    False       False
# 8800    False  False  False      True   True     True       False
# 8801    False  False  False     False  False    False       False
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df["cast"].fillna("", inplace = True)
df["country"].fillna("", inplace = True)
# Out:
# C:\Users\romai\AppData\Local\Temp\ipykernel_18892\4294962891.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cast"].fillna("", inplace = True)
# C:\Users\romai\AppData\Local\Temp\ipykernel_18892\4294962891.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# your code
titles_and_cast={}

temp=df[df["cast"]!="None"]

j=0
for i in temp["title"] :
    titles_and_cast[i]= temp.iloc[j,4]
    j+=1
print(titles_and_cast)
# Out:
# {'Dick Johnson Is Dead': '', 'Blood & Water': 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng', 'Ganglands': 'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera', 'Jailbirds New Orleans': '', 'Kota Factory': 'Mayur More, Jitendra Kumar, Ranjan Raj, Alam Khan, Ahsaas Channa, Revathi Pillai, Urvi Singh, Arun Kumar', 'Midnight Mass': 'Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver', 'My Little Pony: A New Generation': 'Vanessa Hudgens, Kimiko Glenn, James M
# ...

# %% [markdown]
# 8- Using the "titles_and_cast" dictionary, write a piece of code to find out how many times "Ryan Reynolds" played in a movie or a TV show. Print the titles.

# %%
# your code
count=0
for key, value in titles_and_cast.items():
    print(value)
    if value.find("Ryan Reynolds")!=-1:
        count+=1
        print(key)
# Out:
# Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng
# Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera
#
# Mayur More, Jitendra Kumar, Ranjan Raj, Alam Khan, Ahsaas Channa, Revathi Pillai, Urvi Singh, Arun Kumar
# Kate Siegel, Zach Gilford, Hamish Linklater, Henry Thomas, Kristin Lehman, Samantha Sloyan, Igby Rigney, Rahul Kohli, Annarah Cymone, Annabeth Gish, Alex Essoe, Rahul Abburi, Matt Biedel, Michael Trucco, Crystal Balint, Louis Oliver
# Vanessa Hudgens, Kimiko Glenn, James Marsden, Sofia Carson, Liza Koshy, Ken Jeong, Elizabeth Perkins, Jane Krakowski, Michael McKean, Phil LaMarr
# ...

# %% [markdown]
# 9- Using the "titles_and_cast" dictionary, write a piece of code to find out how many times "Ryan Reynolds" and "Blake Lively" played in a movie or a TV show together. Print the titles.

# %%
# your code
count=0
for key, value in titles_and_cast.items():
    if value.find("Ryan Reynolds")!=-1 and value.find("Blake Lively")!=-1:
        count+=1
        print(key)
        print(value)
# Out:
# Green Lantern
# Ryan Reynolds, Blake Lively, Peter Sarsgaard, Mark Strong, Tim Robbins, Jay O. Sanders, Taika Waititi, Angela Bassett

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# 10- Create a new DataFrame from the dataset where the first column is the individual countries and the second column represents the total number of __movies__ produced by that country.
#
# __Note 1__: Check the values in the country column, you might have several country names for a movie.
#
# __Note 2__: Lower and strip the name of each country in order to gather all the counts. This will help you to calculate cumulative values.

# %%
titles_by_country = {}

for index, row in df[["type", "country"]].iterrows():
    if row["type"] == "Movie":
        for w in row["country"].split(","):
            if w.strip().lower() not in titles_by_country.keys():
                titles_by_country[ w.strip().lower() ] = 1
            else:
                titles_by_country[ w.strip().lower() ] += 1

# %%
titles_by_country = pd.DataFrame(data=titles_by_country.items(), columns=["country", "total movies"])
titles_by_country
# Out:
#             country  total movies
# 0     united states          2749
# 1                             446
# 2             ghana             5
# 3      burkina faso             1
# 4    united kingdom           534
# ..              ...           ...
# 113           sudan             1
# 114          panama             1
# 115          uganda             1
# 116    east germany             1
# 117      montenegro             1
#
# [118 rows x 2 columns]

# %% [markdown]
# 11- Create a bar plot of the countries with more than 100 movies in the dataset.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,5))

mask = titles_by_country["total movies"] > 100
titles_by_country = titles_by_country.loc[mask]
ax.bar( titles_by_country["country"], titles_by_country["total movies"] )

ax.set_title("Movies per country")
# Out:
# Text(0.5, 1.0, 'Movies per country')

# %% [markdown]
# ---
